# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./DataSet/Kaggle_YourCabs_score.csv', sep=",")

# %%
df
# Out:
#           id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0     132516    22179                12         NaN               2
# 1     132529    22187                65         NaN               2
# 2     132532    23180                12         NaN               2
# 3     132547    30849                12         NaN               2
# 4     132548    22198                12         NaN               2
# 5     132549    22199                12         NaN               2
# 6     132554    12997                12         NaN               2
# 7     132560    20380                12         NaN               2
# 8     132562    21635                85         NaN               2
# 9     132565      403                28         NaN               2
# 10    132575    22215                12         NaN               2
# 11    132582    22218                12         NaN               2
# 12    132584    22219                12         NaN               2
# ...

# %%
df.head()
# Out:
#        id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0  132516    22179                12         NaN               2
# 1  132529    22187                65         NaN               2
# 2  132532    23180                12         NaN               2
# 3  132547    30849                12         NaN               2
# 4  132548    22198                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id       from_date to_date  \
# 0        1096.0       393.0           NaN         NaN   1/1/2013 9:30     NaN
# 1        1061.0       393.0           NaN         NaN   1/2/2013 1:00     NaN
# 2        1192.0       353.0           NaN         NaN   1/2/2013 4:30     NaN
# 3         515.0       849.0           NaN         NaN  1/1/2013 20:15     NaN
# 4          83.0       463.0           NaN         NaN   1/3/2013 0:30     NaN
#
#    online_booking  mobile_site_booking booking_created   from_lat  from_long  \
# ...

# %%
df.tail()
# Out:
#           id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 9995  185906    48708                12         NaN               2
# 9996  185913    48712                90         NaN               2
# 9997  185925    48720                12         NaN               2
# 9998  185934    22936                12         NaN               2
# 9999  185942    30220                12         NaN               2
#
#       from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# 9995        1026.0      1194.0          15.0         NaN  11/24/2013 11:00
# 9996        1133.0       167.0          15.0         NaN  11/24/2013 16:30
# 9997         363.0       393.0          15.0         NaN  11/26/2013 16:30
# 9998        1330.0      1371.0          15.0         NaN   11/25/2013 3:00
# 9999         585.0      1226.0          15.0         NaN   11/25/2013 7:15
#
#          to_date  online_booking  mobile_site_booking   booking_created  \
# ...

# %%
print("'''PreProcessing DataSet Stage 1:")
print("Replacing NaN in the dataset with zeros'''")
# Out:
# '''PreProcessing DataSet Stage 1:
# Replacing NaN in the dataset with zeros'''

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#           id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0     132516    22179                12         0.0               2
# 1     132529    22187                65         0.0               2
# 2     132532    23180                12         0.0               2
# 3     132547    30849                12         0.0               2
# 4     132548    22198                12         0.0               2
# 5     132549    22199                12         0.0               2
# 6     132554    12997                12         0.0               2
# 7     132560    20380                12         0.0               2
# 8     132562    21635                85         0.0               2
# 9     132565      403                28         0.0               2
# 10    132575    22215                12         0.0               2
# 11    132582    22218                12         0.0               2
# 12    132584    22219                12         0.0               2
# ...

# %%
df["from_city_id"].unique()
# Out:
# array([ 0., 15.,  1.])

# %%
df.describe()
# Out:
#                  id       user_id  vehicle_model_id    package_id  \
# count   10000.00000  10000.000000      10000.000000  10000.000000
# mean   159316.14840  30809.319500         25.866200      0.358000
# std     15346.19683  10950.656449         26.942199      0.975875
# min    132516.00000     11.000000         10.000000      0.000000
# 25%    146221.75000  24871.250000         12.000000      0.000000
# 50%    159140.50000  31631.000000         12.000000      0.000000
# 75%    172623.25000  38935.000000         24.000000      0.000000
# max    185942.00000  48720.000000         91.000000      7.000000
#
#        travel_type_id  from_area_id    to_area_id  from_city_id    to_city_id  \
# count    10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean         2.142000    718.114400    528.417300      5.541400      2.410700
# std          0.441424    420.022484    450.651391      7.238268     15.486026
# ...

# %%
df.to_csv("./DataSet/PreProcessedDataSet.csv")

# %%
ndf = pd.read_csv("./DataSet/PreProcessedDataSet.csv")

# %%
ndf.head()
# Out:
#    Unnamed: 0      id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0           0  132516    22179                12         0.0               2
# 1           1  132529    22187                65         0.0               2
# 2           2  132532    23180                12         0.0               2
# 3           3  132547    30849                12         0.0               2
# 4           4  132548    22198                12         0.0               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id     ...      to_date  \
# 0        1096.0       393.0           0.0         0.0     ...            0
# 1        1061.0       393.0           0.0         0.0     ...            0
# 2        1192.0       353.0           0.0         0.0     ...            0
# 3         515.0       849.0           0.0         0.0     ...            0
# 4          83.0       463.0           0.0         0.0     ...            0
#
# ...

# %%
print("The co-relation between the attributes and the final response.")
ndf.corr()
# Out:
# The co-relation between the attributes and the final response.
#                      Unnamed: 0        id   user_id  vehicle_model_id  \
# Unnamed: 0             1.000000  0.999967  0.591051          0.054957
# id                     0.999967  1.000000  0.591190          0.055131
# user_id                0.591051  0.591190  1.000000          0.060363
# vehicle_model_id       0.054957  0.055131  0.060363          1.000000
# package_id             0.131477  0.131729  0.050657          0.021088
# travel_type_id         0.016500  0.016498 -0.032887         -0.050388
# from_area_id           0.020624  0.020511  0.007887         -0.027626
# to_area_id             0.003865  0.003661  0.014380         -0.055761
# from_city_id           0.703749  0.703135  0.424472          0.046457
# to_city_id             0.008830  0.008962  0.029864          0.109906
# online_booking         0.100388  0.100447  0.090247          0.014436
# ...
